# %%
from pathlib import Path

toml_files = [
    file if file.is_file() else None for file in Path("../../.backups/").glob("*.toml")
]

# %%
# !pwd
# Out:
# /home/tgross/PythonProjects/backpy/backpy/core

# %%
toml_files
# Out:
# [PosixPath('../../.backups/test.toml')]

# %%
a
